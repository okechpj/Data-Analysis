# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data.xlsx")
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-02-01           35          7  Sunny
# 2 2017-03-01           28          2   snow
# 3 2017-04-01           24          7   snow
# 4 2017-05-01           32          4   Rain
# 5 2017-06-01           32          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df.head(3)
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-02-01           35          7  Sunny
# 2 2017-03-01           28          2   snow

# %%
df.tail(2)
# Out:
#          day  temperature  windspeed  event
# 4 2017-05-01           32          4   Rain
# 5 2017-06-01           32          2  Sunny

# %%
df[2:5]
# Out:
#          day  temperature  windspeed event
# 2 2017-03-01           28          2  snow
# 3 2017-04-01           24          7  snow
# 4 2017-05-01           32          4  Rain

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     snow
# 3     snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
df[["event", 'day']]
# Out:
#    event        day
# 0   Rain 2017-01-01
# 1  Sunny 2017-02-01
# 2   snow 2017-03-01
# 3   snow 2017-04-01
# 4   Rain 2017-05-01
# 5  Sunny 2017-06-01

# %%
df["temperature"].max()
# Out:
# 35

# %%
df["temperature"].min()
# Out:
# 24

# %%
df.describe()
# Out:
#                        day  temperature  windspeed
# count                    6     6.000000   6.000000
# mean   2017-03-17 04:00:00    30.500000   4.666667
# min    2017-01-01 00:00:00    24.000000   2.000000
# 25%    2017-02-08 00:00:00    29.000000   2.500000
# 50%    2017-03-16 12:00:00    32.000000   5.000000
# 75%    2017-04-23 12:00:00    32.000000   6.750000
# max    2017-06-01 00:00:00    35.000000   7.000000
# std                    NaN     3.885872   2.338090

# %%
df[df.temperature >=32]
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-02-01           35          7  Sunny
# 4 2017-05-01           32          4   Rain
# 5 2017-06-01           32          2  Sunny

# %%
df.temperature.max()
# Out:
# 35

# %%
df[df.temperature == df.temperature.max()]
# Out:
#          day  temperature  windspeed  event
# 1 2017-02-01           35          7  Sunny

# %%
df[['day', 'temperature']][df.temperature == df.temperature.max()]
# Out:
#          day  temperature
# 1 2017-02-01           35

# %%
df.replace("Sunny", pd.NA, inplace=True)
df
# Out:
#          day  temperature  windspeed event
# 0 2017-01-01           32          6  Rain
# 1 2017-02-01           35          7  <NA>
# 2 2017-03-01           28          2  snow
# 3 2017-04-01           24          7  snow
# 4 2017-05-01           32          4  Rain
# 5 2017-06-01           32          2  <NA>

# %%
df
# Out:
#          day  temperature  windspeed
# 0 2017-01-01         32.0          6
# 1 2017-02-01          NaN          7
# 2 2017-03-01         28.0          2
# 3 2017-04-01         24.0          7
# 4 2017-05-01         32.0          4
# 5 2017-06-01         32.0          2

# %%
df.replace(32, pd.NA)
# Out:
#          day temperature  windspeed  event
# 0 2017-01-01        <NA>          6   Rain
# 1 2017-02-01          35          7  Sunny
# 2 2017-03-01          28          2   snow
# 3 2017-04-01          24          7   snow
# 4 2017-05-01        <NA>          4   Rain
# 5 2017-06-01        <NA>          2  Sunny

# %%
df.at[1, "temperature"] = np.nan
df
# Out:
#          day  temperature  windspeed event
# 0 2017-01-01         32.0          6  Rain
# 1 2017-02-01          NaN          7  <NA>
# 2 2017-03-01         28.0          2  snow
# 3 2017-04-01         24.0          7  snow
# 4 2017-05-01         32.0          4  Rain
# 5 2017-06-01         32.0          2  <NA>

# %%
rows =[1,5] 
columns = ['event','event']

df.loc[rows, columns] = np.nan
df
# Out:
#          day  temperature  windspeed event event
# 0 2017-01-01         32.0          6  Rain  Rain
# 1 2017-02-01          NaN          7   NaN   NaN
# 2 2017-03-01         28.0          2  snow  snow
# 3 2017-04-01         24.0          7  snow  snow
# 4 2017-05-01         32.0          4  Rain  Rain
# 5 2017-06-01         32.0          2   NaN   NaN

# %%
#rows =[1,5] 
#columns = ['event']

#df.loc[rows, columns] = np.nan


df = df.replace({
    'temperature': 32,
    'event':'Sunny'
}, np.nan)

df
# Out:
#          day  temperature  windspeed event
# 0 2017-01-01          NaN          6  Rain
# 1 2017-02-01         35.0          7   NaN
# 2 2017-03-01         28.0          2  snow
# 3 2017-04-01         24.0          7  snow
# 4 2017-05-01          NaN          4  Rain
# 5 2017-06-01          NaN          2   NaN

# %%
df
# Out:
#          day  temperature  windspeed event
# 0 2017-01-01           32          6  Rain
# 1 2017-02-01           35          7   NaN
# 2 2017-03-01           28          2  snow
# 3 2017-04-01           24          7  snow
# 4 2017-05-01           32          4  Rain
# 5 2017-06-01           32          2   NaN

# %%
new_df = df.fillna(0)
new_df
# Out:
#          day  temperature  windspeed event
# 0 2017-01-01          0.0          6  Rain
# 1 2017-02-01         35.0          7     0
# 2 2017-03-01         28.0          2  snow
# 3 2017-04-01         24.0          7  snow
# 4 2017-05-01          0.0          4  Rain
# 5 2017-06-01          0.0          2     0

# %%
new_df = df.fillna({
    'day' : 0,
    'temperature':0,
    'windspeed':0,
    'event' :'no event'
})
new_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01           32          6      Rain
# 1 2017-02-01           35          7  no event
# 2 2017-03-01           28          2      snow
# 3 2017-04-01           24          7      snow
# 4 2017-05-01           32          4      Rain
# 5 2017-06-01           32          2  no event

# %%
new_df = df.fillna(method="ffill")
new_df
# Out:
#          day  temperature  windspeed event
# 0 2017-01-01           32          6  Rain
# 1 2017-02-01           35          7  Rain
# 2 2017-03-01           28          2  snow
# 3 2017-04-01           24          7  snow
# 4 2017-05-01           32          4  Rain
# 5 2017-06-01           32          2  Rain

# %%
new_df = df.replace(32, np.nan, inplace=True)

# %%
new_df
# Out:
#          day  temperature  windspeed event
# 0 2017-01-01          0.0          6  Rain
# 1 2017-02-01         35.0          7     0
# 2 2017-03-01         28.0          2  snow
# 3 2017-04-01         24.0          7  snow
# 4 2017-05-01          0.0          4  Rain
# 5 2017-06-01          0.0          2     0

# %%
new_df = df.fillna({
    'temperature':0,
    'event':"no event"
})
new_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01          0.0          6      Rain
# 1 2017-02-01         35.0          7  no event
# 2 2017-03-01         28.0          2      snow
# 3 2017-04-01         24.0          7      snow
# 4 2017-05-01          0.0          4      Rain
# 5 2017-06-01          0.0          2  no event

# %%
new_df = df.interpolate()
new_df
# Out:
#          day  temperature  windspeed event
# 0 2017-01-01          NaN          6  Rain
# 1 2017-02-01         35.0          7   NaN
# 2 2017-03-01         28.0          2  snow
# 3 2017-04-01         24.0          7  snow
# 4 2017-05-01         24.0          4  Rain
# 5 2017-06-01         24.0          2   NaN

# %% [markdown]
# # group data
#
# df.groupby("city")

# %%
df
# Out:
#          day  temperature  windspeed event
# 0 2017-01-01          NaN          6  Rain
# 1 2017-02-01         35.0          7   NaN
# 2 2017-03-01         28.0          2  snow
# 3 2017-04-01         24.0          7  snow
# 4 2017-05-01          NaN          4  Rain
# 5 2017-06-01          NaN          2   NaN
